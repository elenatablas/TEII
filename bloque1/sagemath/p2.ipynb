# %%
P = matrix(RDF ,[[0.575, 0.118, 0.172, 0.109, 0.026],[0.453, 0.243, 0.148,
0.123, 0.033],[0.104, 0.343, 0.367, 0.167, 0.019],[0.015, 0.066, 0.318,
0.505, 0.096],[0, 0.06, 0.149, 0.567, 0.224]])

# %%
show(P)
# Out:
# [0.575 0.118 0.172 0.109 0.026]
# [0.453 0.243 0.148 0.123 0.033]
# [0.104 0.343 0.367 0.167 0.019]
# [0.015 0.066 0.318 0.505 0.096]
# [  0.0  0.06 0.149 0.567 0.224]

# %%
show("P=",P," Valores propios:", P.eigenvalues())
p=P.characteristic_polynomial(); show("p(x)= ",p)
# Out:
# 'P=' [0.575 0.118 0.172 0.109 0.026]
# [0.453 0.243 0.148 0.123 0.033]
# [0.104 0.343 0.367 0.167 0.019]
# [0.015 0.066 0.318 0.505 0.096]
# [  0.0  0.06 0.149 0.567 0.224] ' Valores propios:' [0.9999999999999997,
#  0.5186197230692187,
#  0.1649479877814734 + 0.06960706942667634*I,
#  0.1649479877814734 - 0.06960706942667634*I,
#  0.06548430136783491]
# 'p(x)= ' x^5 - 1.914*x^4 + 1.172708*x^3 - 0.28863402200000005*x^2 + 0.031014587780000047*x - 0.0010885657800000226
